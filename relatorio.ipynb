# %%
import pandas as pd
import tkinter

relatorio = pd.read_csv

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 262.6 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/11.0 MB 262.6 kB/s eta 0:00:42
#    ---------------------------------------- 0.1/11.0 MB 272.3 kB/s eta 0:00:41
#    ---------------------------------------- 0.1/11.0 MB 280.5 kB/s eta 0:00:39
#    ---------------------------------------- 0.1/11.0 MB 399.4 kB/s eta 0:00:28
#     --------------------------------------- 0.2/11.0 MB 437.1 kB/s eta 0:00:25
# ...
